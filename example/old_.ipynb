# %%
from tabulate import tabulate
DOC = '../docs-src/source/_static/'

def savefig(plot, name):
    plot.savefig(
        fname = DOC+name,
        pad_inches=0.05,
        dpi=200,
        bbox_inches="tight",
        transparent=True
    )
    return plot

def md_table(df):
    print(tabulate(df, tablefmt="pipe", headers="keys"))
    
def rst_table(df):
    print(tabulate(df, tablefmt="rst", headers="keys"))

# %%
import inspect
for name, other in inspect.getmembers(es.Multiple):
    print(name)
# Out:
# _Multiple__compute
# _Multiple__compute_CAR_dist
# _Multiple__warn_errors
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# error_report
# from_csv
# from_list
# from_text
# get_CAR_dist
# plot
# rank_test
# results
# sign_test

# %% [markdown]
# # Get Started

# %% [markdown]
# ## Preliminary work
#
# 1. Load the eventstudy module and its dependencies: numpy and matplotlib:

# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../'))
import eventstudy as es
from eventstudy import excelExporter

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Set the parameters needed for your events: the returns and Fama-French factors (using es.import_returns()and es.import_FamaFrench()):

# %%
es.Single.import_returns('returns_small.csv')
es.Single.import_FamaFrench('famafrench.csv')

# %% [markdown]
# ## Example 1: A single event
#
# As an introductory example, we will compute the event study analysis of the announcement of the first iphone, made by Steve Jobs during MacWorld exhibition, on January 7, 2007.
#
# 1. Run the event study, here using the Fama-French 3-factor model:

# %%
event = es.Single.market_model(
    security_ticker = 'AAPL',
    market_ticker = 'SPY',
    event_date = np.datetime64('2007-01-09'),
    event_window = (-5,+20), 
    estimation_size = 300,
    buffer_size = 30
)

event.to_excel('export.xlsx', chart_as_picture=True)

# %% [markdown]
# 2. Display results:
#     - In a plot:
#         - grey area: confidence interval (here at 90%)
#         - blue line: CAAR
#         - black bars: AR (displayed because AR parameter is set as True)

# %%
savefig(event.plot(AR=True),'single_event_plot.png')
plt.show()

# %%
eventFF = es.Single.constant_mean(
    security_ticker = 'AAPL',
    market_ticker = 'SPY',
    event_date = np.datetime64('2007-01-09'),
    event_window = (-5,+20), 
    estimation_size = 300,
    buffer_size = 30
)
eventFF.plot(AR=True)

# %% [markdown]
# 2. Or in a table:

# %%
event.results(decimals=[3,5,3,5,2,2])
# Out:
#        AR  Variance AR       CAR  Variance CAR  T-stat  P-value
# -5  0.053      0.00049  0.053 **       0.00049    2.39     0.01
# -4 -0.011      0.00049   0.042 *       0.00099    1.34     0.09
# -3  0.017      0.00049    0.06 *       0.00148    1.55     0.06
# -2  0.004      0.00049   0.063 *       0.00197    1.43     0.08
# -1 -0.003      0.00049      0.06       0.00247    1.21     0.11
# 0   0.080      0.00049   0.14 **       0.00296    2.57     0.01
# 1   0.040      0.00049  0.18 ***       0.00345    3.07     0.00
# 2  -0.020      0.00049   0.16 **       0.00394    2.55     0.01
# 3  -0.025      0.00049  0.135 **       0.00444    2.02     0.02
# 4   0.028      0.00049  0.162 **       0.00493    2.31     0.01
# 5  -0.024      0.00049  0.138 **       0.00542    1.87     0.03
# 6  -0.060      0.00049     0.078       0.00592    1.01     0.16
# 7  -0.011      0.00049     0.067       0.00641    0.84     0.20
# 8  -0.016      0.00049     0.051       0.00690    0.62     0.27
# 9  -0.018      0.00049     0.033       0.00740    0.38     0.35
# 10 -0.002      0.00049     0.031       0.00789    0.35     0.36
# 11  0.012      0.00049     0.043       0.00838    0.47     0.32
# 12 -0.010      0.00049     0.033       0.00888    0.35     0.36
# 13  0.006      0.00049     0.039       0.00937    0.40     0.34
# 14 -0.014      0.00049     0.025       0.00986    0.25     0.40
# 15 -0.009      0.00049     0.016       0.01036    0.15     0.44
# 16 -0.022      0.00049    -0.006       0.01085   -0.06     0.48
# 17 -0.003      0.00049     -0.01       0.01134   -0.09     0.46
# 18 -0.011      0.00049    -0.021       0.01183   -0.19     0.42
# 19  0.001      0.00049     -0.02       0.01233   -0.18     0.43
# 20  0.019      0.00049    -0.001       0.01282   -0.01     0.50

# %% [markdown]
# ## Example 2: A sample of events

# %%
AAPL_10K = es.Multiple.from_csv(
    'AAPL_10K.csv',
    es.Single.FamaFrench_3factor,
    event_window = (-10,+10),
    date_format = '%d/%m/%Y'
)
# Out:
# WARNING:root: 3 events have not been processed due to data issues.
# Tips: Get more details on errors by calling EventStudyBatch.error_report() method or by exploring EventStudyBatch.errors class variable.

# %%
print(AAPL_10K.error_report())
# Out:
# Error Report
# ============
#
# 3 errors due to data unavailability.
# The respective events was not processed and thus removed from the sample.
# It does not affect the computation of other events.
#
# Help 1: Check if the company was quoted at this date,
# Help 2: For event study modelised used Fama-French models,
#         check if the Fama-French dataset imported is up-to-date.
# Tips:   Re-import all parameters and re-run the event study analysis.
#
# Details
# =======
# (You can find more details on errors in the documentation.)
#
# Error              Date                       Parameters
# ------------------ -------------------------- -----------------------------------------
# DateMissingError   2019-10-05T00:00:00.000000 security_ticker: AAPL; market_ticker: SPY
# Description: Date (2019-10-05T00:00:00.000000) is missing in parameter: FamaFrench.
#
# DateMissingError   2019-10-05T00:00:00.000000 security_ticker: MSFT; market_ticker: SPY
# Description: Date (2019-10-05T00:00:00.000000) is missing in parameter: FamaFrench.
#
# ColumnMissingError 2019-10-05T00:00:00.000000 security_ticker: GOOG; market_ticker: SPY
# Description: GOOG ticker is not available in returns parameter.
# ------------------ -------------------------- -----------------------------------------

# %%
AAPL_10K.plot()
plt.show()
AAPL_10K.results(decimals = [3,5,3,5,2,2])
AAPL_10K.get_CAR_dist(4)
# Out:
#        Mean  Variance  Kurtosis     Min  Quantile 25%  Quantile 50%  \
# -10  0.0035    0.0011    9.2783 -0.0721       -0.0060       -0.0009
# -9   0.0029    0.0015    6.2955 -0.1249       -0.0096        0.0035
# -8   0.0030    0.0030    2.9118 -0.1589       -0.0206       -0.0044
# -7   0.0001    0.0043    2.5740 -0.2057       -0.0251       -0.0074
# -6  -0.0055    0.0060    2.3077 -0.2237       -0.0268        0.0028
# -5  -0.0051    0.0058    1.5730 -0.2068       -0.0312        0.0069
# -4  -0.0031    0.0069    1.3944 -0.2072       -0.0343        0.0055
# -3  -0.0125    0.0076    0.3780 -0.2120       -0.0545       -0.0013
# -2  -0.0160    0.0071    0.4174 -0.2214       -0.0588       -0.0036
# -1  -0.0237    0.0073   -0.5522 -0.2001       -0.0675       -0.0264
# 0   -0.0236    0.0074   -0.2834 -0.2316       -0.0791       -0.0136
# 1   -0.0172    0.0078   -0.4066 -0.2147       -0.0689       -0.0101
# 2   -0.0229    0.0079    0.3547 -0.2603       -0.0745       -0.0183
# 3   -0.0229    0.0077    1.0592 -0.2743       -0.0576       -0.0170
# 4   -0.0162    0.0077    0.8031 -0.2594       -0.0567        0.0058
# 5   -0.0172    0.0084    0.6790 -0.2657       -0.0492        0.0048
# 6   -0.0206    0.0087    0.0906 -0.2477       -0.0553       -0.0037
# 7   -0.0180    0.0083   -0.1520 -0.2124       -0.0517        0.0025
# 8   -0.0238    0.0078   -0.3326 -0.2080       -0.0578        0.0054
# 9   -0.0177    0.0081    0.2669 -0.2023       -0.0470       -0.0015
# 10  -0.0294    0.0120    0.3303 -0.2963       -0.0530        0.0010
#
#      Quantile 75%     Max
# -10        0.0051  0.1387
# -9         0.0101  0.1306
# -8         0.0196  0.1518
# -7         0.0264  0.1525
# -6         0.0231  0.1497
# -5         0.0247  0.1548
# -4         0.0347  0.2080
# -3         0.0395  0.1905
# -2         0.0350  0.1749
# -1         0.0214  0.1314
# 0          0.0372  0.1225
# 1          0.0339  0.1422
# 2          0.0319  0.1272
# 3          0.0205  0.1136
# 4          0.0346  0.1221
# 5          0.0326  0.1366
# 6          0.0414  0.1368
# 7          0.0307  0.1841
# 8          0.0258  0.1295
# 9          0.0289  0.1965
# 10         0.0233  0.2020

# %%
CM = es.Single.constant_mean('AAPL',
        np.datetime64('2013-03-04'),
        event_window = (-2,+10), 
        estimation_size = 300,
        buffer_size = 30)

CM.plot()
plt.show()
CM.results()
# Out:
#        AR  Variance AR        CAR  Variance CAR  T-stat  P-value
# -2 -0.008          0.0     -0.008         0.000  -0.408    0.342
# -1 -0.026          0.0     -0.034         0.001  -1.229    0.110
# 0  -0.025          0.0  -0.059 **         0.001  -1.755    0.040
# 1   0.025          0.0     -0.034         0.002  -0.870    0.193
# 2  -0.014          0.0     -0.047         0.002  -1.090    0.138
# 3   0.011          0.0     -0.037         0.002  -0.770    0.221
# 4   0.002          0.0     -0.035         0.003  -0.677    0.249
# 5   0.013          0.0     -0.021         0.003  -0.390    0.348
# 6  -0.023          0.0     -0.044         0.003  -0.755    0.225
# 7  -0.001          0.0     -0.045         0.004  -0.732    0.232
# 8   0.009          0.0     -0.036         0.004  -0.561    0.288
# 9   0.025          0.0     -0.011         0.005  -0.170    0.432
# 10  0.026          0.0      0.015         0.005   0.208    0.418

# %%
MM = es.Single.market_model('AAPL','SPY',
        event_date = np.datetime64('2013-03-04'),
        event_window = (-10,+10), 
        estimation_size = 400,
        buffer_size = 30)

MM.plot()
plt.show()

MM.results()
# Out:
#         AR  Variance AR         CAR  Variance CAR  T-stat  P-value
# -10 -0.014          0.0      -0.014         0.000  -0.930    0.176
# -9  -0.008          0.0      -0.022         0.000  -1.028    0.152
# -8  -0.015          0.0    -0.036 *         0.001  -1.409    0.080
# -7  -0.002          0.0      -0.038         0.001  -1.286    0.100
# -6   0.001          0.0      -0.037         0.001  -1.113    0.133
# -5  -0.002          0.0      -0.039         0.001  -1.080    0.140
# -4   0.007          0.0      -0.032         0.002  -0.822    0.206
# -3  -0.022          0.0      -0.054         0.002  -1.283    0.100
# -2  -0.006          0.0     -0.06 *         0.002  -1.354    0.088
# -1  -0.029          0.0   -0.089 **         0.002  -1.899    0.029
# 0   -0.030          0.0  -0.119 ***         0.002  -2.420    0.008
# 1    0.017          0.0   -0.102 **         0.003  -1.979    0.024
# 2   -0.015          0.0   -0.117 **         0.003  -2.180    0.015
# 3    0.009          0.0   -0.108 **         0.003  -1.940    0.027
# 4   -0.002          0.0    -0.11 **         0.003  -1.908    0.029
# 5    0.010          0.0     -0.1 **         0.004  -1.681    0.047
# 6   -0.021          0.0   -0.121 **         0.004  -1.971    0.025
# 7   -0.002          0.0   -0.123 **         0.004  -1.953    0.026
# 8    0.004          0.0   -0.119 **         0.004  -1.838    0.033
# 9    0.029          0.0     -0.09 *         0.004  -1.348    0.089
# 10   0.031          0.0      -0.059         0.005  -0.866    0.194

# %%
#January 9, 2007

iphone1 = es.Single.FamaFrench_3factor('AAPL',
        event_date = np.datetime64('2007-01-09'),
        event_window = (-5,+20), 
        estimation_size = 300,
        buffer_size = 30)

iphone1.plot()
plt.show()

print(tabulate(iphone1.results(), tablefmt="pipe", headers="keys"))
# Out:
# |    |     AR |   Variance AR | CAR       |   Variance CAR |   T-stat |   P-value |
# |---:|-------:|--------------:|:----------|---------------:|---------:|----------:|
# | -5 |  0.053 |             0 | 0.053 *** |          0     |    2.418 |     0.008 |
# | -4 | -0.012 |             0 | 0.041 *   |          0.001 |    1.327 |     0.093 |
# | -3 |  0.013 |             0 | 0.055 *   |          0.001 |    1.435 |     0.076 |
# | -2 | -0.004 |             0 | 0.051     |          0.002 |    1.152 |     0.125 |
# | -1 | -0     |             0 | 0.051     |          0.002 |    1.03  |     0.152 |
# |  0 |  0.077 |             0 | 0.128 *** |          0.003 |    2.374 |     0.009 |
# |  1 |  0.039 |             0 | 0.167 *** |          0.003 |    2.877 |     0.002 |
# |  2 | -0.027 |             0 | 0.14 **   |          0.004 |    2.261 |     0.012 |
# |  3 | -0.024 |             0 | 0.116 **  |          0.004 |    1.767 |     0.039 |
# |  4 |  0.024 |             0 | 0.14 **   |          0.005 |    2.02  |     0.022 |
# |  5 | -0.023 |             0 | 0.117 *   |          0.005 |    1.607 |     0.055 |
# |  6 | -0.057 |             0 | 0.06      |          0.006 |    0.793 |     0.214 |
# |  7 | -0.011 |             0 | 0.049     |          0.006 |    0.621 |     0.267 |
# |  8 | -0.011 |             0 | 0.038     |          0.007 |    0.465 |     0.321 |
# |  9 | -0.017 |             0 | 0.021     |          0.007 |    0.245 |     0.403 |
# | 10 | -0.003 |             0 | 0.018     |          0.008 |    0.204 |     0.419 |
# | 11 |  0.01  |             0 | 0.028     |          0.008 |    0.305 |     0.38  |
# | 12 | -0.008 |             0 | 0.02      |          0.009 |    0.211 |     0.417 |
# | 13 |  0.009 |             0 | 0.028     |          0.009 |    0.298 |     0.383 |
# | 14 | -0.012 |             0 | 0.016     |          0.01  |    0.165 |     0.435 |
# | 15 | -0.011 |             0 | 0.005     |          0.01  |    0.054 |     0.479 |
# | 16 | -0.024 |             0 | -0.018    |          0.011 |   -0.179 |     0.429 |
# | 17 | -0.001 |             0 | -0.019    |          0.011 |   -0.183 |     0.427 |
# | 18 | -0.009 |             0 | -0.028    |          0.012 |   -0.262 |     0.397 |
# | 19 |  0.002 |             0 | -0.026    |          0.012 |   -0.238 |     0.406 |
# | 20 |  0.02  |             0 | -0.006    |          0.013 |   -0.056 |     0.478 |

# %% [markdown]
# # Other

# %%
es.Single.import_returns('sgen.csv',is_price = True, date_format = '%d/%m/%Y')

# %%
CASC = es.Single.FamaFrench_3factor('CASC',np.datetime64("2018-01-31"),(-5,+5), estimation_size=200, buffer_size=20)

# %%
CASC.plot()
